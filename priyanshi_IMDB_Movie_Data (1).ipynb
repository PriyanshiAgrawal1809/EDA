# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("D:\desktop\eda\IMDB-Movie-Data.csv")
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
# 1. Display Top 10 Rows of The Dataset
df.head(10)
# Out:
#    Rank                    Title                       Genre  \
# 0     1  Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 1     2               Prometheus    Adventure,Mystery,Sci-Fi
# 2     3                    Split             Horror,Thriller
# 3     4                     Sing     Animation,Comedy,Family
# 4     5            Suicide Squad    Action,Adventure,Fantasy
# 5     6           The Great Wall    Action,Adventure,Fantasy
# 6     7               La La Land          Comedy,Drama,Music
# 7     8                 Mindhorn                      Comedy
# 8     9       The Lost City of Z  Action,Adventure,Biography
# 9    10               Passengers     Adventure,Drama,Romance
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# ...

# %%
# 2. Check Last 10 Rows of The Dataset
df.tail(10)
# Out:
#      Rank                           Title                     Genre  \
# 990   991  Underworld: Rise of the Lycans  Action,Adventure,Fantasy
# 991   992                Taare Zameen Par        Drama,Family,Music
# 992   993            Take Me Home Tonight      Comedy,Drama,Romance
# 993   994        Resident Evil: Afterlife   Action,Adventure,Horror
# 994   995                       Project X                    Comedy
# 995   996            Secret in Their Eyes       Crime,Drama,Mystery
# 996   997                 Hostel: Part II                    Horror
# 997   998          Step Up 2: The Streets       Drama,Music,Romance
# 998   999                    Search Party          Adventure,Comedy
# 999  1000                      Nine Lives     Comedy,Family,Fantasy
#
#                                            Description            Director  \
# 990  An origins story centered on the centuries-old...  Patrick Tatopoulos
# ...

# %%
# 3. Find Shape of Our Dataset (Number of Rows And Number of Columns)
df.shape
# Out:
# (1000, 12)

# %%
# 4. Getting Information About Our Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column And Memory Requirement
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %%
# 5. Check Missing Values In The Dataset
df.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
# 6. Drop All The  Missing Values

# df['Revenue (Millions)'].dropna( axis = 0 , how = all , inplace=True)
df.dropna(inplace=True)

# %%
# 7. Check For Duplicate Data
df.duplicated().sum()
# Out:
# 0

# %%
# 8. Get Overall Statistics About The DataFrame
df.describe()
# Out:
#               Rank        Year  Runtime (Minutes)      Rating         Votes  \
# count   838.000000   838.00000         838.000000  838.000000  8.380000e+02
# mean    485.247017  2012.50716         114.638425    6.814320  1.932303e+05
# std     286.572065     3.17236          18.470922    0.877754  1.930990e+05
# min       1.000000  2006.00000          66.000000    1.900000  1.780000e+02
# 25%     238.250000  2010.00000         101.000000    6.300000  6.127650e+04
# 50%     475.500000  2013.00000         112.000000    6.900000  1.368795e+05
# 75%     729.750000  2015.00000         124.000000    7.500000  2.710830e+05
# max    1000.000000  2016.00000         187.000000    9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          838.000000  838.000000
# mean            84.564558   59.575179
# std            104.520227   16.952416
# min              0.000000   11.000000
# 25%             13.967500   47.000000
# 50%             48.150000   60.000000
# ...

# %%
# 9. Display Title of The Movie Having Runtime Greater Than or equal to 180 Minutes
# df.groupby('Title')['Runtime (Minutes)']<=180
df[df['Runtime (Minutes)'] >= 180]['Title']
# df[df['Runtime (Minutes)'] >= 180]
# Out:
# 82     The Wolf of Wall Street
# 88           The Hateful Eight
# 311             La vie d'Adèle
# Name: Title, dtype: object

# %%
# 10. In Which Year There Was The Highest Average Voting?
df.groupby('Year')['Votes'].mean().idxmax()
# Out:
# 2012

# %%
# 11. In Which Year There Was The Highest Average Revenue?
df.groupby('Year')['Revenue (Millions)'].mean().idxmax()
# Out:
# 2009

# %%
# 12. Find The Average Rating For Each Director
df.groupby('Director')['Rating'].mean()
# Out:
# Director
# Aamir Khan             8.50
# Abdellatif Kechiche    7.80
# Adam McKay             7.00
# Adam Shankman          6.30
# Adam Wingard           5.90
#                        ...
# Xavier Dolan           8.10
# Yimou Zhang            6.10
# Yorgos Lanthimos       7.20
# Zack Snyder            7.04
# Zackary Adler          5.10
# Name: Rating, Length: 524, dtype: float64

# %%
# 13. Display Top 10 Lengthy Movies Title and Runtime

df.groupby('Title')['Runtime (Minutes)'].mean().nlargest(10)

# Top_10_lengthy_movies_title=df.sort_values(by='Revenue (Millions)', ascending=False).head(10)
# Top_10_lengthy_movies_title[['Title','Runtime (Minutes)']]
# Out:
# Title
# The Hateful Eight                           187.0
# La vie d'Adèle                              180.0
# The Wolf of Wall Street                     180.0
# Cloud Atlas                                 172.0
# 3 Idiots                                    170.0
# Interstellar                                169.0
# Pirates of the Caribbean: At World's End    169.0
# The Hobbit: An Unexpected Journey           169.0
# The Curious Case of Benjamin Button         166.0
# Australia                                   165.0
# Name: Runtime (Minutes), dtype: float64

# %%
# 14. Display Number of Movies Per Year
df.groupby('Year')['Title'].count()
# Out:
# Year
# 2006     41
# 2007     44
# 2008     48
# 2009     45
# 2010     57
# 2011     57
# 2012     62
# 2013     84
# 2014     93
# 2015    109
# 2016    198
# Name: Title, dtype: int64

# %%
# 15. Find Most Popular Movie Title (Highest Revenue)

df.groupby('Title')['Revenue (Millions)'].mean().nlargest()
# Out:
# Title
# Star Wars: Episode VII - The Force Awakens    936.63
# Avatar                                        760.51
# Jurassic World                                652.18
# The Avengers                                  623.28
# The Dark Knight                               533.32
# Name: Revenue (Millions), dtype: float64

# %%
# 16. Display Top 10 Highest Rated Movie Titles And its Directors
# 1st method
# top_10_highest_rated_movies = df.nlargest(10, 'Rating')
# for index, row in top_10_highest_rated_movies.iterrows():
#     print("Title:", row['Title'])
#     print("Director:", row['Director'])
#     print()

# 2nd method
# df.groupby(['Rating', 'Title', 'Director'])

# 3rd method
df.sort_values(by= 'Rating' ,ascending=False).head(10)
# Out:
#      Rank                  Title                    Genre  \
# 54     55        The Dark Knight       Action,Crime,Drama
# 80     81              Inception  Action,Adventure,Sci-Fi
# 36     37           Interstellar   Adventure,Drama,Sci-Fi
# 249   250       The Intouchables   Biography,Comedy,Drama
# 96     97          Kimi no na wa  Animation,Drama,Fantasy
# 124   125  The Dark Knight Rises          Action,Thriller
# 991   992       Taare Zameen Par       Drama,Family,Music
# 133   134               Whiplash              Drama,Music
# 99    100           The Departed     Crime,Drama,Thriller
# 476   477    The Lives of Others           Drama,Thriller
#
#                                            Description  \
# 54   When the menace known as the Joker wreaks havo...
# 80   A thief, who steals corporate secrets through ...
# 36   A team of explorers travel through a wormhole ...
# 249  After he becomes a quadriplegic from a paragli...
# ...

# %%
# 17. Display Top 10 Highest Revenue Movie Titles
df.groupby('Title')['Revenue (Millions)'].mean().nlargest(10)
# Out:
# Title
# Star Wars: Episode VII - The Force Awakens    936.63
# Avatar                                        760.51
# Jurassic World                                652.18
# The Avengers                                  623.28
# The Dark Knight                               533.32
# Rogue One                                     532.17
# Finding Dory                                  486.29
# Avengers: Age of Ultron                       458.99
# The Dark Knight Rises                         448.13
# The Hunger Games: Catching Fire               424.65
# Name: Revenue (Millions), dtype: float64

# %%
# 18.  Find Average Rating of Movies Year Wise
df.groupby('Year')['Rating'].mean()
# Out:
# Year
# 2006    7.143902
# 2007    7.140909
# 2008    6.708333
# 2009    6.911111
# 2010    6.894737
# 2011    6.945614
# 2012    6.933871
# 2013    6.832143
# 2014    6.822581
# 2015    6.674312
# 2016    6.644444
# Name: Rating, dtype: float64

# %%
# 19. Does Rating Affect The Revenue?
# 1st method 
df['Rating'].corr(df['Revenue (Millions)'])

# 2nd method 
# Affecting=df['Rating'].corr(df['Revenue (Millions)'])
# if Affecting > 0:
#     print( "Rating is affecting the Revenue")
# elif Affecting < 0:
#     print("Rating is not affecting the Revenue")
# Out:
# 0.21710577610381881

# %%
# 20. Classify Movies Based on Ratings [Excellent, Good, and Average]
def rating_classification(rating):
    if rating >= 8.0:
        return "Excellent"
    elif rating >= 6.0:
        return "Good"
    else:
        return "Average"
df['Rating_Category'] = df['Rating'].apply(rating_classification)
Classification=df.groupby('Rating_Category')['Title'].count()
Classification
# Out:
# Rating_Category
# Average      128
# Excellent     70
# Good         640
# Name: Title, dtype: int64

# %%
# 21. Count Number of Action Movies
df[df['Genre'].str.contains('Action' , case = False)]['Genre'].count()
# Out:
# 277

# %%
# 22. Find Unique Values From Genre 
df['Genre'].unique()
# df['Genre'].nunique()
# Out:
# array(['Action,Adventure,Sci-Fi', 'Adventure,Mystery,Sci-Fi',
#        'Horror,Thriller', 'Animation,Comedy,Family',
#        'Action,Adventure,Fantasy', 'Comedy,Drama,Music',
#        'Action,Adventure,Biography', 'Adventure,Drama,Romance',
#        'Adventure,Family,Fantasy', 'Biography,Drama,History',
#        'Animation,Adventure,Comedy', 'Action,Comedy,Drama',
#        'Action,Thriller', 'Biography,Drama', 'Drama,Mystery,Sci-Fi',
#        'Adventure,Drama,Thriller', 'Drama', 'Comedy',
#        'Action,Adventure,Drama', 'Drama,Thriller',
#        'Action,Adventure,Comedy', 'Action,Horror,Sci-Fi',
#        'Adventure,Drama,Sci-Fi', 'Action,Adventure,Western',
#        'Comedy,Drama', 'Action,Crime,Thriller', 'Action,Crime,Drama',
#        'Adventure,Drama,History', 'Crime,Horror,Thriller',
#        'Drama,Romance', 'Comedy,Drama,Romance', 'Crime,Drama,Mystery',
#        'Drama,Romance,Thriller', 'Drama,History,Thriller',
# ...

# %%
# 23. How Many Films of Each Genre Were Made?
df.groupby('Genre')['Title'].count()
# Out:
# Genre
# Action                         1
# Action,Adventure               3
# Action,Adventure,Biography     2
# Action,Adventure,Comedy       14
# Action,Adventure,Crime         6
#                               ..
# Mystery,Sci-Fi,Thriller        3
# Mystery,Thriller               6
# Sci-Fi                         1
# Sci-Fi,Thriller                1
# Thriller                       1
# Name: Title, Length: 189, dtype: int64
