# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("D:\desktop\eda\IPL DATA SET.csv")
df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
# 1.FIND TOP 10 ROWS OF A DATASET
df.head(10)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
# 2.CHECK FOR THE INFORMATION ABOUT A DATA FRAME
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
# 3.CHECK THE SHAPE OF A DATASET
df.shape
# Out:
# (756, 18)

# %%
# 4.FIND OUT THE NAN VALUES
df.isnull().sum().sum()
# Out:
# 656

# %%
# 5.CHECK FOR STATISTICAL INFORMATION ABOUT DATA SET
df.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
# 6.HOW MANY MATCHES WERE PLAYED IN TOTAL ACCORDING TO A DATASET.
len(df)
# Out:
# 756

# %%
# 7.HOW MANY IPL SEASONS ARE WE USING TO ANALYZE.
SEASONS = df['season'].unique()
len(SEASONS)
# Out:
# 12

# %%
# 8.WHICH IPL TEAM WON BY SCORING THE MAXIMUM RUNS?
# df.groupby('winner')['win_by_runs'].max()
df.groupby('winner')['win_by_runs'].max().idxmax() # idxmax = to show the maximum no of id 
# df.groupby('winner')['win_by_runs'].max().max()   # to show maximum number of amount
# Out:
# 'Mumbai Indians'

# %%
# 9.WHICH IPL TEAM WON BY CONSUMING MAXIMUM WICKETS?
df.groupby('winner')['win_by_wickets'].max().idxmax()
# Out:
# 'Chennai Super Kings'

# %%
# 10.WHICH IPL TEAM WON BY CONSUMING MINIMUM WICKETS?
df.groupby('winner')['win_by_wickets'].min().idxmin()
# Out:
# 'Chennai Super Kings'

# %%
df.groupby(['winner','win_by_wickets']) # this is allowed when only we made group by 
                                        # it is not allowed when we give a arragument like ... .min() , .idxmax()

# %%
# 11.WHICH SEASON CONSISTED OF THE HIGHEST NUMBER OF MATCHES EVER PLAYED?
df.groupby('season')['date'].count().idxmax()
# Out:
# 2013

# %%
# 12.WHICH IS THE MOST SUCCESSFUL IPL TEAM WITH ALL THE DATA AT A HAND?
df.groupby('winner')['winner'].count().idxmax()
# Out:
# 'Mumbai Indians'

# %%
# 13.WHAT IS THE PROBABLITY OF WINNING A MATCH IF THE TOSS WAS WON?
df.groupby('winner')['toss_winner'].count().sum()
# Out:
# 752

# %%
#Q-13 - WHAT IS THE PROBABLITY OF WINNING A MATCH IF THE TOSS WAS WON?
total_toss_won = df['toss_winner'].count()
print(total_toss_won)
# Count the number of matches won after winning the toss
matches_won_after_toss_won = df[(df['toss_winner'] == df['winner'])].shape[0]
print(matches_won_after_toss_won)
# Calculate the probability
probability = (matches_won_after_toss_won / total_toss_won) * 100
print("Probability of Winning after Winning Toss:", probability)
# Out:
# 756
# 393
# Probability of Winning after Winning Toss: 51.98412698412699

# %%
# 14.CHECK FOR HIGHEST WINS BY TEAMS PER SEASON
df.groupby('winner')['season'].max().idxmax()
# Out:
# 'Chennai Super Kings'

# %%
# 15.CHECK FOR MAN OF THE MATCH --HIGHEST TO LOWEST(IN WON MATCHES)
df.groupby('winner')['player_of_match'].count()
# Out:
# winner
# Chennai Super Kings            100
# Deccan Chargers                 29
# Delhi Capitals                  10
# Delhi Daredevils                67
# Gujarat Lions                   13
# Kings XI Punjab                 82
# Kochi Tuskers Kerala             6
# Kolkata Knight Riders           92
# Mumbai Indians                 109
# Pune Warriors                   12
# Rajasthan Royals                75
# Rising Pune Supergiant          10
# Rising Pune Supergiants          5
# Royal Challengers Bangalore     84
# Sunrisers Hyderabad             58
# Name: player_of_match, dtype: int64

# %%
# 16.IN WHICH CITY WERE THE NUMBER OF MATCHES PLAYED?
df.groupby('city')['city'].count()
# Out:
# city
# Abu Dhabi           7
# Ahmedabad          12
# Bangalore          66
# Bengaluru          14
# Bloemfontein        2
# Cape Town           7
# Centurion          12
# Chandigarh         46
# Chennai            57
# Cuttack             7
# Delhi              74
# Dharamsala          9
# Durban             15
# East London         3
# Hyderabad          64
# Indore              9
# Jaipur             47
# Johannesburg        8
# Kanpur              4
# Kimberley           3
# Kochi               5
# Kolkata            77
# Mohali             10
# Mumbai            101
# Nagpur              3
# Port Elizabeth      7
# Pune               38
# Raipur              6
# Rajkot             10
# Ranchi              7
# Sharjah             6
# Visakhapatnam      13
# Name: city, dtype: int64

# %%
df.groupby('city')['city'].count().idxmax()
# Out:
# 'Mumbai'
